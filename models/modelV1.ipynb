# %%
import pandas as pd

# %%
df = pd.read_csv('../data/convertData/finland_electricity_predict_dataset.csv')
df
# Out:
#                   datetime   price  Air temperature mean [°C]  \
# 0      2023-01-01 00:00:00    4.84                   4.433333
# 1      2023-01-01 01:00:00    2.01                   4.100000
# 2      2023-01-01 02:00:00    1.38                   3.800000
# 3      2023-01-01 03:00:00    0.09                   3.616667
# 4      2023-01-01 04:00:00    0.08                   2.516667
# ...                    ...     ...                        ...
# 26299  2025-12-31 19:00:00  152.00                 -14.666667
# 26300  2025-12-31 20:00:00  140.00                 -14.100000
# 26301  2025-12-31 21:00:00  131.41                 -15.050000
# 26302  2025-12-31 22:00:00  129.91                 -15.600000
# 26303  2025-12-31 23:00:00  115.73                 -15.716667
#
#        Wind speed mean [m/s]
# 0                   8.516667
# 1                   7.716667
# 2                   8.150000
# 3                   9.333333
# 4                  11.700000
# ...                      ...
# 26299               4.500000
# 26300               4.650000
# 26301               4.716667
# 26302               4.600000
# 26303               4.100000
#
# [26304 rows x 4 columns]

# %% [markdown]
# # Create train & test data set

# %%
#drop the target variable and the datetime column from the feature set
X = df.drop(columns = ['price', 'datetime'])

#set the dependent variable
y = df['price']

# %%
from sklearn.model_selection import train_test_split

# spliting the data into training, testing and validation sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, shuffle=False)

# %%
X_train.shape
# Out:
# (21043, 2)

# %%
X_test.shape
# Out:
# (5261, 2)

# %% [markdown]
# # TRAIN V1 XG-BOOST REGRESSION MODEL

# %%
from xgboost import XGBRegressor
from sklearn.metrics import mean_absolute_error

# %%
#instantiate the model with default hyperparameters
model_v1 = XGBRegressor(n_estimators=100, random_state=42)

print("Starting training V1 baseline model...")
# Out:
# Starting training V1 baseline model...

# %%
#train the model on the training data
model_v1.fit(X_train, y_train)

print("Training finished! Starting testing...")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 2
#       1 #train the model on the training data
# ----> 2 model_v1.fit(X_train, y_train)
#       3
#       4 print("Training finished! Starting testing...")
#
# File d:\Software\Python3.12\Lib\site-packages\xgboost\core.py:751, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     749 for k, arg in zip(sig.parameters, args):
#     750     kwargs[k] = arg
# --> 751 return func(**kwargs)
#
# File d:\Software\Python3.12\Lib\site-packages\xgboost\sklearn.py:1343, in XGBModel.fit(self, X, y, sample_weight, base_margin, eval_set, verbose, xgb_model, sample_weight_eval_set, base_margin_eval_set, feature_weights)
#    1340 model, feature_types = get_model_categories(X, model, self.feature_types)
#    1342 evals_result: EvalsLog = {}
# -> 1343 train_dmatrix, evals = _wrap_evaluation_matrices(
#    1344     missing=self.missing,
#    1345     X=X,
#    1346     y=y,
#    1347     group=None,
#    1348     qid=None,
#    1349     sample_weight=sample_weight,
#    1350     base_margin=base_margin,
#    1351     feature_weights=feature_weights,
#    1352     eval_set=eval_set,
#    1353     sample_weight_eval_set=sample_weight_eval_set,
#    1354     base_margin_eval_set=base_margin_eval_set,
#    1355     eval_group=None,
#    1356     eval_qid=None,
#    1357     create_dmatrix=self._create_dmatrix,
#    1358     enable_categorical=self.enable_categorical,
#    1359     feature_types=feature_types,
#    1360 )
#    1362 if callable(self.objective):
#    1363     obj: Optional[PlainObj] = _objective_decorator(self.objective)
#
# File d:\Software\Python3.12\Lib\site-packages\xgboost\sklearn.py:700, in _wrap_evaluation_matrices(missing, X, y, group, qid, sample_weight, base_margin, feature_weights, eval_set, sample_weight_eval_set, base_margin_eval_set, eval_group, eval_qid, create_dmatrix, enable_categorical, feature_types)
#     695 """Convert array_like evaluation matrices into DMatrix. Perform sanity checks on the
#     696 way.
#     697
#     698 """
#     699 # Feature_types contains the optional reference categories from the booster object.
# --> 700 train_dmatrix = create_dmatrix(
#     701     data=X,
#     702     label=y,
#     703     group=group,
#     704     qid=qid,
#     705     weight=sample_weight,
#     706     base_margin=base_margin,
#     707     feature_weights=feature_weights,
#     708     missing=missing,
#     709     enable_categorical=enable_categorical,
#     710     feature_types=feature_types,
#     711     ref=None,
#     712 )
#     714 n_validation = 0 if eval_set is None else len(eval_set)
#     715 if hasattr(train_dmatrix, "get_categories"):
#
# File d:\Software\Python3.12\Lib\site-packages\xgboost\sklearn.py:1257, in XGBModel._create_dmatrix(self, ref, **kwargs)
#    1255 if _can_use_qdm(self.tree_method, self.device) and self.booster != "gblinear":
#    1256     try:
# -> 1257         return QuantileDMatrix(
#    1258             **kwargs, ref=ref, nthread=self.n_jobs, max_bin=self.max_bin
#    1259         )
#    1260     except TypeError:  # `QuantileDMatrix` supports lesser types than DMatrix
#    1261         pass
#
# File d:\Software\Python3.12\Lib\site-packages\xgboost\core.py:751, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     749 for k, arg in zip(sig.parameters, args):
#     750     kwargs[k] = arg
# --> 751 return func(**kwargs)
#
# File d:\Software\Python3.12\Lib\site-packages\xgboost\core.py:1719, in QuantileDMatrix.__init__(self, data, label, weight, base_margin, missing, silent, feature_names, feature_types, nthread, max_bin, ref, group, qid, label_lower_bound, label_upper_bound, feature_weights, enable_categorical, max_quantile_batches, data_split_mode)
#    1699     if any(
#    1700         info is not None
#    1701         for info in (
#    (...)   1712         )
#    1713     ):
#    1714         raise ValueError(
#    1715             "If data iterator is used as input, data like label should be "
#    1716             "specified as batch argument."
#    1717         )
# -> 1719 self._init(
#    1720     data,
#    1721     ref=ref,
#    1722     label=label,
#    1723     weight=weight,
#    1724     base_margin=base_margin,
#    1725     group=group,
#    1726     qid=qid,
#    1727     label_lower_bound=label_lower_bound,
#    1728     label_upper_bound=label_upper_bound,
#    1729     feature_weights=feature_weights,
#    1730     feature_names=feature_names,
#    1731     feature_types=feature_types,
#    1732     enable_categorical=enable_categorical,
#    1733     max_quantile_blocks=max_quantile_batches,
#    1734 )
#
# File d:\Software\Python3.12\Lib\site-packages\xgboost\core.py:1783, in QuantileDMatrix._init(self, data, ref, enable_categorical, max_quantile_blocks, **meta)
#    1768 config = make_jcargs(
#    1769     nthread=self.nthread,
#    1770     missing=self.missing,
#    1771     max_bin=self.max_bin,
#    1772     max_quantile_blocks=max_quantile_blocks,
#    1773 )
#    1774 ret = _LIB.XGQuantileDMatrixCreateFromCallback(
#    1775     None,
#    1776     it.proxy.handle,
#    (...)   1781     ctypes.byref(handle),
#    1782 )
# -> 1783 it.reraise()
#    1784 # delay check_call to throw intermediate exception first
#    1785 _check_call(ret)
#
# File d:\Software\Python3.12\Lib\site-packages\xgboost\core.py:594, in DataIter.reraise(self)
#     592 exc = self._exception
#     593 self._exception = None
# --> 594 raise exc
#
# File d:\Software\Python3.12\Lib\site-packages\xgboost\core.py:575, in DataIter._handle_exception(self, fn, dft_ret)
#     572     return dft_ret
#     574 try:
# --> 575     return fn()
#     576 except Exception as e:  # pylint: disable=broad-except
#     577     # Defer the exception in order to return 0 and stop the iteration.
#     578     # Exception inside a ctype callback function has no effect except
#     579     # for printing to stderr (doesn't stop the execution).
#     580     tb = sys.exc_info()[2]
#
# File d:\Software\Python3.12\Lib\site-packages\xgboost\core.py:662, in DataIter._next_wrapper.<locals>.<lambda>()
#     660     self._temporary_data = None
#     661 # pylint: disable=not-callable
# --> 662 return self._handle_exception(lambda: int(self.next(input_data)), 0)
#
# File d:\Software\Python3.12\Lib\site-packages\xgboost\data.py:1642, in SingleBatchInternalIter.next(self, input_data)
#    1640     return False
#    1641 self.it += 1
# -> 1642 input_data(**self.kwargs)
#    1643 return True
#
# File d:\Software\Python3.12\Lib\site-packages\xgboost\core.py:751, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     749 for k, arg in zip(sig.parameters, args):
#     750     kwargs[k] = arg
# --> 751 return func(**kwargs)
#
# File d:\Software\Python3.12\Lib\site-packages\xgboost\core.py:651, in DataIter._next_wrapper.<locals>.input_data(data, feature_names, feature_types, **kwargs)
#     649 self._temporary_data = (new, feature_names, feature_types)
#     650 dispatch_proxy_set_data(self.proxy, new)
# --> 651 self.proxy.set_info(
#     652     feature_names=feature_names,
#     653     feature_types=feature_types,
#     654     **kwargs,
#     655 )
#     656 self._data_ref = ref
#
# File d:\Software\Python3.12\Lib\site-packages\xgboost\core.py:751, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     749 for k, arg in zip(sig.parameters, args):
#     750     kwargs[k] = arg
# --> 751 return func(**kwargs)
#
# File d:\Software\Python3.12\Lib\site-packages\xgboost\core.py:1066, in DMatrix.set_info(self, label, weight, base_margin, group, qid, label_lower_bound, label_upper_bound, feature_names, feature_types, feature_weights)
#    1064     self.set_float_info("label_upper_bound", label_upper_bound)
#    1065 if feature_names is not None:
# -> 1066     self.feature_names = feature_names
#    1067 if feature_types is not None:
#    1068     self.feature_types = feature_types
#
# File d:\Software\Python3.12\Lib\site-packages\xgboost\core.py:1469, in DMatrix.feature_names(self, feature_names)
#    1464 # prohibit the use symbols that may affect parsing. e.g. []<
#    1465 if not all(
#    1466     isinstance(f, str) and not any(x in f for x in ["[", "]", "<"])
#    1467     for f in feature_names
#    1468 ):
# -> 1469     raise ValueError(
#    1470         "feature_names must be string, and may not contain [, ] or <"
#    1471     )
#    1473 feature_names_bytes = [bytes(f, encoding="utf-8") for f in feature_names]
#    1474 c_feature_names = (ctypes.c_char_p * len(feature_names_bytes))(
#    1475     *feature_names_bytes
#    1476 )
#
# ValueError: feature_names must be string, and may not contain [, ] or <
